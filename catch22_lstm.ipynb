# %% [markdown]
# <a href="https://colab.research.google.com/github/bmcnns/catch22_lstm_textgen/blob/main/catch22_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This method was adapted from Francois Chollet's [Deep Learning With Python](https://www.manning.com/books/deep-learning-with-python)
#
# This notebook is an exercise from Chapter 8: Generative deep learning
# adapted to take sequences from a pdf of Joseph Heller's Catch 22
# that is saved at "my_data/catch22.pdf".
#
# Chollet, Francois. (2017). Deep learning with Python. Shelter Island, NY: Manning Publications Co.

# %% [markdown]
# Dependencies:
#    - pypdf2: for reading PDF files

# %%
 # !pip install pypdf2

# %% [markdown]
# # Collect a large dataset of text that you want the model to learn from. This could be a corpus of books, articles, or any other type of text.

# %%
# Collect a large dataset of text that you want the model to learn from.
# This could be a corpus of books, articles or any other type of text.

import PyPDF2

# Open the PDF file in read-binary mode
with open('my_data/catch22.pdf', 'rb') as file:
  pdf = PyPDF2.PdfFileReader(file)
  text = ''

  for i in range(pdf.getNumPages()):
    page_text = pdf.getPage(i).extractText()
  
    # Append the page text to the overall text
    text += page_text

  text = text.lower()

# Preprocess the text by removing PDF header information.
header_length = 186
text = text[header_length:]

# Convert the text to lowercase
text = text.lower()

print('Corpus Length', len(text))
# Out:
# Corpus Length 1039509

# %% [markdown]
# # Preprocess the text data by extracting partially overlapping sequences of length maxlen, one-hot encode them and then packing them in a 3D Numpy array x of shape (sequences, maxlen, unique_characters)

# %%
import numpy as np

# Extracting sequences of 60 characters.
maxlen = 60

#You'll sample a new sequence every 3 characters.
step = 3

# Holds the extracted sequences
sentences = []

# Holds the targets
next_chars = []

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i: i + maxlen])
  next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

# Dictionary that maps unique characters to their index in the list "chars"
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
# One-hot encodes the characters into binary arrays.
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i, t, char_indices[char]] = 1
  y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 346483
# Unique characters: 60
# Vectorization...

# %% [markdown]
# # Build the model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Define the model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
# Fit the model to the training data
model.fit(x, y, epochs=10, batch_size=128)
# Out:
# Epoch 1/10
# 2707/2707 [==============================] - 25s 7ms/step - loss: 2.3818 - accuracy: 0.3194
# Epoch 2/10
# 2707/2707 [==============================] - 18s 7ms/step - loss: 2.0129 - accuracy: 0.4070
# Epoch 3/10
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.8792 - accuracy: 0.4438
# Epoch 4/10
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.7901 - accuracy: 0.4686
# Epoch 5/10
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.7213 - accuracy: 0.4885
# Epoch 6/10
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.6686 - accuracy: 0.5040
# Epoch 7/10
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.6267 - accuracy: 0.5157
# Epoch 8/10
# 2707/2707 [==============================] - 18s 7ms/step - loss: 1.5914 - accuracy: 0.5246
# Epoch 9/10
# 2707/2707 [==============================] - 18s 7ms/step - loss: 1.5611 - accuracy: 0.5325
# Epoch 10/10
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.5356 - accuracy: 0.5398

# %% [markdown]
# :

# %% [markdown]
# Sampling from the soft-max distribution of the model

# %%
# The higher the temperature, the higher the entropy of the sampling.
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %% [markdown]
# The temperature parameter controls the randomness or unpredictability of the generated text. A higher temperature will result in more random or unpredictable text, while a lower temperature will result in more predictable text. This is because the temperature affects the entropy (randomness) of the sampling process.
#
# The function returns the index of the element with the highest probability in the resulting sample.

# %% [markdown]
# # Generating Text

# %%
import random
import sys

for epoch in range(1, 60):
  print('epoch', epoch)
  model.fit(x, y, batch_size=128, epochs=1)

  # Selects a text seed at random
  start_index = random.randint(0, len(text) - maxlen - 1)
  generated_text = text[start_index: start_index + maxlen]
  print('--- Generating with seed: "' + generated_text + '"')

  for temperature in [0.2, 0.5, 1.0, 1.2]:
    print('---- temperature:', temperature)
    for i in range(400):
      # One-hot encodes the characters generated so far
      sampled = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(generated_text):
        sampled[0, t, char_indices[char]] = 1
      
      # Samples the next character
      preds = model.predict(sampled, verbose=0)[0]
      next_index = sample(preds, temperature)
      next_char = chars[next_index]

      generated_text += next_char
      generated_text = generated_text[1:]

      print(next_char, end='')
    print('')
# Out:
# epoch 1
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.4728 - accuracy: 0.5562
# --- Generating with seed: "ht to be glad you've got any temperature at all."
#      doc d"
# ---- temperature: 0.2
# aneeka she was a man of the start of a fell him and start and the should in the start of the started the start of the same the started the start and his forther of his forther the same the same to make a string and the same the started his finter the start and stop of the started the start and shook and the same the started the started the started and streased and the same no distand of the start
# ---- temperature: 0.5
# with his sile the stromm to sise was she sturned his eyes perse of the starting them and the good hought to sight, and when he was a same to berong the store and had colonel cathcart to knop out the concons and then engered the dunbar morning in the strove her orr made or as on a mens on the officers and the the back to danbersting and tome them and was his something and into a panized the but the
# ---- temperature: 1.0
# n doc done odse dewarly displarely, at his questak andersh head and get me." suil the getsion as a back to placmed out, and a resuppout
# came regindizing to man at
# even thousing of queter, is that's anoid on, wend i do all they were all comentine, and i peckemed and he?"
#      "is though you going ivint?" major doc distentqseration a mactefora. how. major durbs that missterzers,
# "is kigndarion, even
# ---- temperature: 1.2
#  quesion, bur thing, busking down eicket rogghor as aftick and
# capttak thas awoudvioued babjer of the otentless was grupping and at he's even senvemente. lame affuldy of tige a bongisench as his prigh,
# as ablitters vicke's shovetate on
# rose, and breay briggus in a
# timed, liver. "we bound we want tow
# were that the bilp voidously tomatos."
#      "nattey costinive over?"
#      "thehe so evorts. mila, a
# epoch 2
# 2707/2707 [==============================] - 18s 7ms/step - loss: 1.4576 - accuracy: 0.5607
# --- Generating with seed: "   "i'm not living in this one alone," yossarian said with a"
# ---- temperature: 0.2
#  start of a frammed and stop and start of the stop and start and start and combat the started at the sent and was a feet and the chaplain was a fly more to the more and combat the chaplain with a breath the contrilated at the floor the chaplain was a fly more to consin and start of a fram and the chaplain was a feet for the streat of a monting and his finder to the started to the start to do befor
# ---- temperature: 0.5
# e he was and the head the word and plane and tring and been the chaplain were a dean to be and start of chaplain bed him and doc daneeka sueded to sight of the bold on the there was a but sugger and broke a but the head the countine and distand milo better of the comine and the best on his finter the most of the some the colonel cathcart tome over a good every never some of the almost him of the c
# ---- temperature: 1.0
# loor were bespoatcant as docture, go of repotiand andovently in. genearly a think grtes am buck and stilly buhbard, fent a brown you, siderstreft what the colonel kill if what you sleep are to dewaing, woll from lighter and more to the sw. the carmawned objecting wanting fist of which i't seemed must, the word became
# returing horoons?"
#      "it abains to want."
#      "then
# thas follord usn of critr
# ---- temperature: 1.2
# ime, peny stremhed ortarod, enough squadred. uch as
# vald clatedinge, go bour. the queitht's appraied did that jackfiend him to
# know an onge." the men clined. "yes, you, lost."
#      the others
# with shair to? if you doing ano demes a plane
# surfuese that
# captain?"
#      the beft one.
# i woshesing a loand everyther just there?"
#      "hh? chasen's green."
#   '  captaim's heawly syiknnifed
# gain and dread.
# epoch 3
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.4439 - accuracy: 0.5643
# --- Generating with seed: "nt every adverb and every adjective.
# the next day he made wa"
# ---- temperature: 0.2
# s strong to was strong his hands to the start of the streating at the streated the streated to his to any the streating the most the streated to the strong the streated the streating and the streated to the strong the streated and the stried the room to his had been the streated to his sime him and the streated and the strong the streating the streath the confice of the streated to the streating t
# ---- temperature: 0.5
# he two shouted to him and he heard the first the group him.
#      "i don't know that's everything to do you think i man was signing to finity streate to the down. it doing was
# brown all and probling to the still his cants the chaplain stopping the but he was the chaplain was surposs of the two strung he was not the one seconded the hospital think hands the started to an helloned to be the shoot for
# ---- temperature: 1.0
#
# which of them for pisticolatedly
# plane in oching his men in a fat enct. and
# him. cothan face.
#      "sertillute's
# grinching go it, puties's face fas. pere to the more him. the and was
# surpeals hathese and whimpardly runele." the one onch comminden, and get a bollow, addicated alone was was dovelted
# sighter craces, for the
# uninelly to lived his hallation outhatil
# had
# get no longing
# in his had kept
#
# ---- temperature: 1.2
# was not he hasta evastick, if i tere whilf you ove
# have a searfory men to promsint,
# the facl.
#      "just let you came me couldn grie doc."
#      "it's daying, you, sirli for that samepness betriining abouting at, mulownason outindy flufty dommenstaps and all nackon exherss and
# joke was over. he was partable rettwert
# glest
# dark.
#  his
# poers les kofblitener vittimate was furry facts tell, waw, sendica
# epoch 4
# 2707/2707 [==============================] - 19s 7ms/step - loss: 1.4310 - accuracy: 0.5681
# --- Generating with seed: "panic of the man screaming for help to the police
# while poli"
# ---- temperature: 0.2
# ng the time they were not to see and shouted to the sent the more of his second and he was a first the first the chaplain was not the chaplain was the controlate of his life the strangers with a strangers and the shoulders and stop of the streating and his head with a start with a strong and down and shouted and she was a feet more the squadron and a start of the streated some of the first the sta
# ---- temperature: 0.5
# re in a scared to his come not that he was a discommering the enders of pay to free in the face that he was mission
# of his lised with a good the controus so on intervound him with a fine the people with the mission. he was exactly of the colonel knowed with a stop the roor and like pumbled at the hospital and from the tall with his own of officers with the streed his his beling for him and was to
# ---- temperature: 1.0
# but repodalate with
# dolmente milo had when to order, they well? pain the charrility. "she a fursesh but his eyes
# deip bulld me, say and all the prefes. milutels throat in dis face-chail door cap, told, him beound highs of the only poojoy of the people said. "do you didn't wondered sight. "i'll hole you."
#      milo smored apound cheeked foue of his had week of his pleaaly back rose, beviltish me. w
# ---- temperature: 1.2
# hen i in,"
#  a grumping oc, to. "we'll,"
#      "is goominged tracish," neated knebyan about her waits eetterm chestlean in a solish, was areat, for
# contor turnagess. agno?"
#      "when they woll me." mcw-26thou, and hit hadd a perkef me.4
#      "generous aid you wonserniign it."
#      forched to collfap? there was you forthout signia," he tene whend he
# kecked
# agne beling sayen:
#      1he
# hulba through t
# epoch 5
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.4198 - accuracy: 0.5704
# --- Generating with seed: "hen. on the judgment day. yes, that's the day i'll be close "
# ---- temperature: 0.2
# in the strange and the man who godded the most the start of the stopped the chaplain back to the start of the same the stop of the floor him and stopped the streated to subbat he was a feet for the man who really a share of the same the stop and looked the start of the streated the streated and the same the stopped the stopped the streated the streated the streated the started to his face and shou
# ---- temperature: 0.5
# ted to so but the war with a clear him for a morting about it and hungry joe here he was a strandly who round him and letter and see, said of him and like a lately and put him and reloing with and man orr major major major danby domn the sected the dows filled and trave to orr was the more courtences. "i cap was all the same of the still the would look so that and the hell we're not to smouthing t
# ---- temperature: 1.0
# o puty," he was just from him to the
# very distrejoned dobb, too, with a sompopt with a heady up there worldy on bastarmommerastly.
#      doctor declared your diest revended," he stop wing away for him weat. repain the getminally alout the roam him and roped to take ithous all high
# better field worl doep to the night
# to all was no knew a mentily; i've would jump with more to page agring to guy by th
# ---- temperature: 1.2
# at wo, yossarian packed. half grew what he crew. "not for nosholder of the
# fly mwint-by clast."
#      "haspey't new him? you follusy him by coulgn't want told."
#      "you can was not sope them," hus oft dunble whose nege surget -then-whers mire doing deen muck."
# he book 37heller with the skeat of the blues querking. why happled?"
#      "tell age mouth murairones ear ropting," did you agat: a remage
# epoch 6
# 2707/2707 [==============================] - 20s 8ms/step - loss: 1.4088 - accuracy: 0.5739
# --- Generating with seed: "ly. he was downcast and burdened with self-reproach when he "
# ---- temperature: 0.2
# was a feet from the chaplain before he was a colonel cathcart was still the streated the streating the still the colonel cathcart was still the first the first the bead the time the tent to see the bead the first the fleak the streated the bombardier in the flew him to be the streated to see the chaplain was still the face the back to stear who was a fine the streated the streating the first the t
# ---- temperature: 0.5
# wo them the fist of a brown. he think he would be surpeated colonel korn answered to same the room with the was a person with his was them tried to group helple and good in the distort with been to the feeling and like different and find of the one of the cold in his poot and from the orderly as he was as of the hower lefule the room the tent before himself a hollowant scheisskopf and then he was
# ---- temperature: 1.0
# near was had been seecity with a group name, was let them has back day
# eashing, with the gram trying blum, he secced about theroked to yossarian looking thime was flithting, coutton at groughher frangines
# profit opebcerserow.
#      "are wosling with that yough in toe see
# at
# tree ir them
# justing she
# stapperd, thouse he was as himsele."
#      "arough
# someys us
# from the edsy to for,
# hel.
#      she was r
# ---- temperature: 1.2
# ols. colonel korg
# busing
# good, londment ve and; havin the ellay, doving thun in time that day, from wasneg, tought unoma hia in readly
# dunbar men
# from howers. suy dobara. 94h, eithenther yor."
#      "any being bore
# interes well ser? what a shood of."
# ho, holdy nevery
# peep that of a wosly aiffedmints and after he give that i'r bed
# falls of aunoosting reaten 5athcallanisstant heakyed himpelf ifters i
# epoch 7
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3993 - accuracy: 0.5759
# --- Generating with seed: "aptist, and that it was therefore neither
# necessary nor corr"
# ---- temperature: 0.2
# on as he had not a flached in the shoulders and the chaplain was a strimples and the officers with a started and was a beally and the time he was a stranger of the officers and shoulded to his liver and parders and the best of the streather and the time he was a flying the started and the sent shoulders and shoulder in the sidely and the shoulder the time of the controlation of his sidele and the
# ---- temperature: 0.5
# two the two she slipped over the armoned to the whole thouse of the shook the distrously and bowed from the later the time and the plane can madquared him away in the startion. he had no sot make the chaplain redomn in a bodsting staid who was a good to the other something and returned to the officers was plane with his own on the secutence men him the head from the chaplain was day so man in the
# ---- temperature: 1.0
# moded under over his pomettesing this felt you in being whom were ners once string each over
# marnet. he did that what good there home colvarge duncera exprefbaging dripping old right chorled. it was a bubbullfortly. ehey,
# passionse strainess irrually felt and they thought
# ho'll memed the gisttent agrite on window. no! do that
# wear over youngled., what'i did the lists," catch-22
# shoudded. i don't b
# ---- temperature: 1.2
# ushed, didn't i just up goyent sandseve to for he medrise to the bomborn-oving donyed, or. "we'd has my," clevinger. "what you bombered what you's jux might spisem?"
#      dunce
# 43heller, jostorira althohs raded, lio urneddably midde sornardes at altholdger dobseant yossarian goun arnowher heally out in itcwatmed down of chemsent, gnemoros. "and shet you right."
#      "gones? as nothing shided."
#
# epoch 8
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3900 - accuracy: 0.5788
# --- Generating with seed: "major major of food, even if major major was a
# communist, wh"
# ---- temperature: 0.2
# o was a brown and began to make a start of the first the most the most the streated to the that he was a strending to the floor of the money in the man was a start of the formorded the face of the colonel cathcart was a feet the most the most and some of the face of the face with a start of the dropped the first the first the face of the told him and the one of the most and something the most of t
# ---- temperature: 0.5
# he floor him and possion who was a fly more to colonel cathcart was still side and his from sergeant to shooting in the back and some that in the contrility. yossarian had going to his fling of minuter from the but face came to the morting and confused at the first the shoulder that major major major said of the colonel had a care with a compressed the first the the month on the faced the month on
# ---- temperature: 1.0
#
# the
# surning and were instarmen boloneming his slimped and and redreet hands pats with
# pull me tomatious as them dayming the nar distroble affeen of conducipied, soffun in his manable of his wife major mission to do you're sold nondy i'r survarit. and you stime?"
#      "he had isked, "nearned isn't he?"
#      "are you withly?"
#      "you did."
#
# "betthrir-"
#      yossarian was my gave himsele. the
# ---- temperature: 1.2
# did not prondy time we'r complogre, colonel cathcart is a book?' dut, mnjoio!" yossarian back to hurned backers of his lotterasked if they had lift.
#      "certaa,"'s they wardin's
# rustsly
# mils foilleation. "why did so you've doctitted moven offitere?"
# yossarian ssone-posted. milo gloigh to regainiantly whore's always, that i-i. will be regumarfum deinged which therels,"
#      colonel korn from the
#
# epoch 9
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3813 - accuracy: 0.5818
# --- Generating with seed: "s were following us around with all their equipment just to "
# ---- temperature: 0.2
# do with a second with a potter to the startion and his fingers and the hospital to she was and the contrite that he was and start and his fingers and the chaplain was a feet and his fingers and his fingers and the chaplain was a prove with a colonel cathcart some the second to the streated and start and the second to the streeted to the part of the chaplain was a feet and the chaplain back and the
# ---- temperature: 0.5
#  forther and still turned to the crazy. "i don't know it's fried and made their in the mart me."
#      "why didn't you the letter we all."
#      "where well, i sudder the fick to say the only isn't the was a sign and the besk man in the men and shook and in the streeted kid save of the chaplain both spot of for a feet redoded and in her in the orderly in the mission when he let his own colonel cathc
# ---- temperature: 1.0
# art's ruared inside the blove outingi? who was ellet working for yiver for aligract of sack to the most look."
#      "i know he's gus? milo had new conceitied."
# ac brome more around time him washen turned him for shimmer when an pared with a goddantly
# in twenty of sezzing infultedly; she yead worlunged unach their slot up knen if his lide out ittomy rutil and crissed. and insedent major than bit it
# ---- temperature: 1.2
#  weethent lotse. old yoar drepped gavial on twee arobs intrity.
# the coloset him with
# ansectiousl had
# forgoss. yossarian grave
# begin look her. bolly's gongual or lieutenanted. mcwats am a fresy, and 8o delocion selliter to alletching the rome, that carefuld the cippord!
# than't be to state me. common't mighled," he repifted carressly. "what whally me. you, i've got to people it, their watged to?"
#
# epoch 10
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3734 - accuracy: 0.5835
# --- Generating with seed: "mouth.
#      "i told you not to do it," colonel korn snickere"
# ---- temperature: 0.2
# d the started the controls with a started to the look the started the time the chaplain was a colonel cathcart was start of the plane of the chaplain was a feet at the controls of the but him and her to the starting the war with a startion to the startion. "i was the most to the most that was that the men that was the street for the brown and sent to his face and paraded and start of the started h
# ---- temperature: 0.5
# im out of the plane and too before with a probing to be a divide the sected with a started and only that major major was fist and repered and lifted all confided the confession to the grew the moated the bombs of the strange to the room with a huplence and and had still decanded with his chaplain for a back to his servelless of the enffort of country read him. "i don't know, i did to the bod, i su
# ---- temperature: 1.0
# ghling about spacatel. colonel? you kien in the short madit with the good merally of thought a tent across for in thouse we dat ortie to   he could out asfuring his enlisted in
# in openess only ex, perid with sumposs to wife a meloratoeses to keppe.
#
#      "this worred."
#      "no ort whize as aare play on the hell overchagbly.' laughation tellost. i can rel. for
# pocile general menosing 3urlike a
# ---- temperature: 1.2
# gnedywon left a
# tenapious in ussald, and denevtonats fidder thinks of suffa helpod lept agning, regulfarm.
# has her through the parking. the levecoooiblosts sene. and sex-id.
# you're corrorination," pangeratuor howtens, urle sudatiy epeded up. "20.      he caundered and the issorte. "this condered more thatke almove." we end. that then
# alone with seeg him, on the genear, at on himselven and alway-du
# epoch 11
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3655 - accuracy: 0.5854
# --- Generating with seed: "ennial
# weeds growing between his rusty soupcan urinal with n"
# ---- temperature: 0.2
# othing and the chaplain was a send the sent all the most and the only the person when he said out of the control to the stop of a milo. he had no something to stop of a from the only the part and shoulder the first the chaplain before he was a clear and the colonel cathcart was stopped the chaplain was almost the chaplain was stopped the control to his face and shoulder with a stranger of a strang
# ---- temperature: 0.5
# less of before on the sent of a share of probing to be to do with a plane almost to a very mobles of person who had no somether and a fele him get at his learing and as he condered to she was some from men while he had no something half and stopped and was running him and there she sot of a second with a briggering his landing and the way the stopped him with the streather of his each and into the
# ---- temperature: 1.0
#  officers' water. "that's a
# chaccal?
# pelway! of ougher jait. major, page 18heller, joseph: catch-22
# haggnesh him haughations him. they had wought anithing on ueto old do an answerbard in the lompthing drabien,
# controd and make milling as were to belen intilled out of the collain, itnembinders who well about you're ain by, before imanow you slopp over with a plead gould to the face voince was almos
# ---- temperature: 1.2
# t runnigatus both haspitian in that deswerently,
# put inunly on colonel forgere as what's puround pointeul walks for liking to cavery back in a saughhopossoly's filling desquadably for up than besweading you. no hearg
# guining up. achiant."
#      urgilizesting by the only share out ap its. they lard and cried spaseded to
# egghinaclisy, and did because they a deap his come.
# ariey, thought they lacked h
# epoch 12
# 2707/2707 [==============================] - 20s 8ms/step - loss: 1.3590 - accuracy: 0.5876
# --- Generating with seed: " out. as
# soon as he did realize it, corporal whitcomb walked"
# ---- temperature: 0.2
#  and the war was a streated and should with a streated and catched the war was a stranger of a stranger of the first the way the profit of the baddant and shouted and was a good and the bead the controlated with a breath his head and the colonel cathcart and the war was a paraded general dreedle was a clove on the one of the colonel cathcart was start and was something to make a second with a man
# ---- temperature: 0.5
# show he was this and wouldn't got a captain black, who protesmed by the one of says it some of the general dreedle's face the armored him and were gratter and been some of the course stand on the emptrice and his life all the flak the one of the good the only the tent for an assical the kept of the name room and that i was stull parade the chaplain brought to do when you see he's place in the word
# ---- temperature: 1.0
# , it you, not good. it's them hand in milo, i don't want you're to do that i did pullogra to dead, what had ever aboth with thet, charthon bedrown" and said man in everywning weralless, and sholled
# enterely with a hand overhing with arriating fingers are who danlers at uncrettled gloat to men't gencia
# die. a, he'd really and don over grying and even there was nother fold, milo squarrocument and hi
# ---- temperature: 1.2
# s hand to maka." organdlely, i'zed. in serve avis, to. home had boend about luy
# you wammed on a darravice right conditile," he
# answered and fuce, strung dive-cures you. now genera, give him lower prepistly here question. asked him.
# "nea-want opfon and and dol's being want
# pivilly."
#      yossarian dineshed rushing that had't nanced liternce he wer. when you punny once yesse it. he wantedly imparte,
# epoch 13
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3518 - accuracy: 0.5891
# --- Generating with seed: "heet, for the food at the mess hall was all still the proper"
# ---- temperature: 0.2
# ate of the trouble and stated to the stop of the stop of the stop of the first to stake and began to the both and replained at the signing the chaplain before he was a hands of the the most the shoulder the chaplain was a feet and the proternan and the orr was a feet of the tranching the signing the barrassion to discord with a states of the shoulder of the street and sating the street and his off
# ---- temperature: 0.5
# icer remorded at the ward and she was discount with a grinning so every sturves to do and colonel cathcart state and stopped away with the chaplain with a clew and same hand and the sail distrolone about the selling his stout a most to branged out all the shouting the stook his stopped for the stariey of a straighter his order up a scurably the shot by the side drove the parable so the bed the squ
# ---- temperature: 1.0
# adron back to room to made the warse again. "but just's cletry to get bastary and fat will you just to yoo, sir. i'm nell those peatently ach in you deneka, sir?"
#      clevinger clebled had redussulal as s blike nies first colvinter them offocer clust assard, and did not intestemed on an andulation boaking trasitian at reading his
# bode and luift. sir-cape dreeklated bread if yoss. "i'm tan always
#
# ---- temperature: 1.2
# vehive. squit! id under able," and her delee
# white. a hatcershivizint) clumely. "that's igrn domy lowdensive.
#      "night it's sickhous leader first for him." she ward looking fyings intengille dreappence.
#      "peligh i fiest over," he scan was very tranttine disisquind.
# he looked balally bottlite."
#      "he didn't got abuliate whem took."
#      "yes. shay on the word 225h looke tumb of fingeas."
# epoch 14
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.3453 - accuracy: 0.5910
# --- Generating with seed: "ave here in my hands now another statement from colonel cath"
# ---- temperature: 0.2
# cart was a but and the chaplain was stopped to the stopped to a colonel cathcart was a but that he was a stranger of a colonel cathcart was a bomb report of a colonel cathcart was a but that was a same that he was surprised to the streated and shouted to the stop of his head and shoulder that he was a started to the second and string of the second commander of the colonel cathcart was a face in th
# ---- temperature: 0.5
# e second something to any ston and shouted to the hungry found at the officers' clevinger was a colonel cathcart started at all the most of me something and space of a colonel cathcart had was carefully to the flush for his time all the shicken so many serve in the with him out man with his own for him and seemed the way chaplain still such his perseng to read money was that there was destroy. yos
# ---- temperature: 1.0
# sarian, where they depreal the general recoes it herriffed out of descubs?"
#      "the cirily that
# each outside?"
#      "no."
# comend and quighes strange sninifes in his cheeking enyose is in a bar, he strew opes at ancenst because he laughable more to the way duspisted the consturquid for he till of courting in a plane and condeal, and sheek like gried on his instrout for chatiented at the but fablu
# ---- temperature: 1.2
# se? with not josy a deavhle. a punny airpets to his vaider of fin then inveliptive because shiving his ufferrats of
# with upen of worse. yossarian muss wherenatide madfes haugh, as they be and brumble buct to grie himser snight
# before lappter was move in the chamgreeked at heaked, apprienters for fendreascy with a sherttardles. heard rane that would remnedence.
#      "orr san on?" ehe
# face a whole m
# epoch 15
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.3394 - accuracy: 0.5930
# --- Generating with seed: "t board picked me right up out of the middle and
# put me down"
# ---- temperature: 0.2
#  and and was a full the streather and the same the face and started and shouted at the stopped to the stop of the face and started and the bomb low and shouted and started at the started the stop of a constion of the started at all the stop and stand them and shouted at the started and started and had been the posting and the bomb stated at the stop of his face and was a confident and started at a
# ---- temperature: 0.5
# ll.
#      "i don't know they want to do with you let me the finger in the man said up to the shart of the colonel cathcart and comple eyes in a but her prother and the colonel cathcart was a lose and instrances comman and man should with a bed the most the most of the colonel frown of with his life had done and still spenger and good him are planes and flumbled the
# brown. he had no sole was a good
# ---- temperature: 1.0
# them. could another been about endlysnicialas behind him in a spelies meen fawly on the milaron for a crorm of carround oppose and and palacted intromped and godded by quesional trying good at him gurilling and
# spored, he head." the conceored hands he knew a thin lave fron chotiently. "i think something to allow every decarmen, sir. i can half! he balky leashed sellowly them unta dute of m & bagun
# ---- temperature: 1.2
# ance cursibeds., do an trestruious,
# bequzer; i'm her
# aptarmar
# opened,
# for that i can haver seer." colonel cathora when a swell hall
# a missingle, "general dreedle as a combain just the
# pament orvin, sontirle, "if you're to dind you
# catcrs appage 102heller," so discense vangers were k. stave tomous eightted"
#      "you're bastanabed," sterrway
# when the shot at a nurking im. but let yossarian struckin
# epoch 16
# 2707/2707 [==============================] - 22s 8ms/step - loss: 1.3331 - accuracy: 0.5948
# --- Generating with seed: "l cathcart's choice of
# major major, captain black muttered t"
# ---- temperature: 0.2
# he war and the back to the way the room to the way the rest of the war and the colonel cathcart was all the chaplain was a same that he was a plane and the way the war and the only the way the wall the chaplain was not the was and the war down the chaplain was a group to the way the chaplain was a hands of the matter the way the chaplain was a stuping the and shoot and the was a sturn and shouted
# ---- temperature: 0.5
# at he was chaplain's flustlessively for the war and the war down on the way the time his ventionating can, when they all the chaplain was all the way the war to came all the appoces of even the war really dising now
# each truise was every car, both here by all spitted out of here all thing of askide until the more. dunbar said. "no, i don't have to do with my condection to keep the plane of cart of
# ---- temperature: 1.0
#  humped the killed broup only that
# heaked the signing with pression felt, want to lieutenant morely digning with but nose who stapped horse about to-your halfoat preys week intigalate missions. and doc deamed mass gut know, louded!
# fortere. unswerenal of hung for yossarian all of the crazy,
# awayblek.
#      when't patay," asked her and who even a plaint, and is nately want the crach up as
# chaplain!
# ---- temperature: 1.2
# a perco-y-first, it was jacketly auring dious.
#      "it do," caget who
# was lownes, ovin? dunbingce he report dushe a bomb
# midgle chinked indenstaffocall. "o the housefy?"
#      ged indred him away now
# of sandy his way major missions, sheating and on rowh because evenic protunging back when she had, it naked yalver over
# farries
# pajor, and how ragged by their oan aarfelaty."
#      "ack
# you'd bee.f!" m
# epoch 17
# 2707/2707 [==============================] - 20s 8ms/step - loss: 1.3273 - accuracy: 0.5965
# --- Generating with seed: "itudinous
# page 10heller, joseph: catch-22
# bedrooms on facing"
# ---- temperature: 0.2
#  a strending and the man was a share of the start of the start of the start of the street and her should and the should him and the shart of the should and start of the stopped and the sent him and he was a bade with him and was a stranger of the start of his head and decane he was a person when he stopped the thing of the stopped and the tranched and the squadron with his head and the same the st
# ---- temperature: 0.5
# reet and snowden break his there was a beit, captain was to his hands and the armuniar of responded in behind the trounted and scareful and with him and despride who had been should hard to him. the colonel care now the morning and wear and i was been a twice to see that colonel cathcart state and she was the men the day of his trues side and should snowden start from the away and blond he was
# as
# ---- temperature: 1.0
# they decide anyween lasped to with hand and the more himself. he in a bredehe crashia enessed pater. yossarian out nosticle
# in the word and
# weir alter jest that day you're abouty winears i spieady windish! mearicaling, whed-all, milo one most meet crangly antomery doing looks of morely answawl of us formider things. all the rooritened ducky. will be catch stip the mome in a fat with deappessests.
# ---- temperature: 1.2
# hear at antounedrest of the fly this trigine trying to wiss his recues every (ath or awars cud to she so musewheysib lying when.
# pagheraty had nurves ofn sidn's high suffort labl on hos ussaasion, bomban it war gus lenders dries you're borking to you! i me. woy outd," ort snakes. etcent's fausher tazy brivent, him-said, back own, will knowdernttered yissequighty rowigion with fan perseorny, and el
# epoch 18
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.3221 - accuracy: 0.5976
# --- Generating with seed: "ticking clock, in the icy rain and wet sand all through the "
# ---- temperature: 0.2
# colonel cathcart was a few some man and the man who was not to the man who was not the man in the man with a street and second to the man in the second more to the stop and the bars of the street to be a shootent and start and start and spind of the man in the stop of the stolen for him and shooted and looking and should be a strong with a start of the colonel cathcart was still had been a hands o
# ---- temperature: 0.5
# f my fatter could ble send to the men had been with around yossarian's shool and the tall can was start and signing the she had felt the squadron stoude again and was he was not to colonel cathcart was all the way to be saverm. the milo and his still the destroy he would not been all the street and running with a good and space when a distrough hand and confide had
# work up that was it about all th
# ---- temperature: 1.0
# e
# cold you find man eat again and mile marrialix everything about him, stay. dunbar had taft stome bombsly again with a litula when he was the tent for untwhered in the very more norstwacted indo the matquaving every home."
#      "apexty ungrilatures," he cot other with an goving him traunting and
# fintagminted with poge in brobosy forma.
#      the let mast
# suspicious, sinciss of pidial pecked.
#
# ---- temperature: 1.2
# "you nello," yossarian was at wanted up into yossarian eet,
# who sollitter pro-perone else that it
# out scenter of
# night at the shoot
# morta. everyone made,
# she oft. crsug doing for no roets sastelly, three caperisser. at the officer and
# love, splaimered his fliftly colonel know. yossarrain he was sugges in them. yossarian had over to flight even a dawsome of much of reg. bick awvercement actiane mal
# epoch 19
# 2707/2707 [==============================] - 20s 8ms/step - loss: 1.3166 - accuracy: 0.5993
# --- Generating with seed: "pefully.
#      "i'm afraid that isn't good enough. have mrs. "
# ---- temperature: 0.2
# i was a share."
#      "well, i don't know what i want to see he wants to see he had to start of the minderson who was a share of the chaplain was a clearing and shouted and the war dead men and was a start of the room to the whole head in the startion and the same the spetion and spinded with a startion to the second and was a start of the colonel cathcart was a ground with a started at the started
# ---- temperature: 0.5
#  with a brimb spased streamed and was said with a crazy in the warm with a speps and spent all the shot at the colonel colonel cathcart to starts to the plane he was a spirs of the about the squadron stapped be and the understanding and propled to make about him and in the man squadron for a share of the solding and was charter almost colonel korn was the finger the chaplain for with growing to be
# ---- temperature: 1.0
#  coment of hopllished in and was horses do and the brobby was not right and were day was charge prefeg up of aky sarpard with a brown insterily when yossarian anound the interventedenul up to go to know, thing all we strend like entrestors becound was woundry felt, he screamed began to start. no skeeted to ble wound her clemb. and then shicked him to fine hurging templaining ain to warming in his
# ---- temperature: 1.2
# cloting with just was this and right
# with spridicasa,
# there got dain what droposist tixires eashned dispassic just," neat kinuris bad, cover with line slickles, and to
# one was anoth-menifawer on the flown helarply a dropphing, man, to advenshulfus half foot a
# his like was in better joleque, two porelypard to said, was the gardable of
# wapped it tury!"
#      milo ainction forder my grew dephoult, thr
# epoch 20
# 2707/2707 [==============================] - 20s 7ms/step - loss: 1.3115 - accuracy: 0.6009
# --- Generating with seed: " the two of them were walking
# side by side toward their own "
# ---- temperature: 0.2
# and started and shoot his head in the stopped at him and the part and still the part of his head and comple reseltes in the parades and the seconds of his face and who had not going to started at the stumbered and the one of the street and still and comple on the fingers and the pilot to discount the streamed and stumbs the man in the streck to the man in the second was a started his seconded in a
# ---- temperature: 0.5
#  steating dispassions of the warn and stopped at the loud and plane began to the end on the distriveles of the streamed until the one of the fleasing to his fising
# began to the loor in the both craw. she was readured in her sigged and the chaplain reseltes of his forgifed in the chips just on his pigged and like and the bead the most the specialy and her in a startion to decerter the flight the de
# ---- temperature: 1.0
# ssed and stapmenteds on the
# boesconsicated. "he im."
#      he
# was and too out to time? don't you have never
# peet that
# right each recrack it throw stofted, as much untifision cut.
#      ccolor elsoned back instants
# formanted to the
# crazy immational formedly pranine agauncenges to lieuously, had was not ever then group, sood in milo rimmelt really told you concented out abaid," there wapted at
# him to
#
# ---- temperature: 1.2
# into for almowdle in an eyes. haverched clizzing morned, buy. he rempecte, was on theithing playing. "as they milute?"'."
#      "no've not isanded us of curnince, git it you weedle periminte!" the tip some terrivicatimeding altho-id him!"
#      "do you medally isnales? you're, they vere sogsant always we'd to an aughinge? i'm to giem."
#      "but they."
#      the jighted them danges tirecsiance, added
# epoch 21
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.3072 - accuracy: 0.6015
# --- Generating with seed: "your laundry?"
# page 140heller, joseph: catch-22
#      the cap"
# ---- temperature: 0.2
# tain was started to the state and comple monemed and the other was a seventer of the stopped to the stumbled to the stopped to the startion and the state of the stopped to the whole head and the plane all the shot and had been to the stopped to the stopped to colonel cathcart was a part and completed in a start to be the same the states and was strending and the started and the strender and the st
# ---- temperature: 0.5
# rengher his head in the stopped fat more. "i can really to keep the second and that he think the over and then he was in the stract of the contracted he was off crazy. "i don't know. put him with out to you."
#      "but it was the same to the griefity detentary and the persanded at the profit of the read the streated and his more compleading to his having to the states and understanding secious eno
# ---- temperature: 1.0
# ugh bomb.
#      "then
# hurged the while any thin "shate "but he's
# doll, he don't six in aby name?"
#      "i candy?" yossarian snipped enze ruminatumbling for ancens words in
# it solution. "o y."      "geveral," the actly regny unstikefy, them. he littles men crudertable comenove clumsligents while the
# loodsing his on the struckled. "dunbar had jair busingling to call, and i howes." support. she head h
# ---- temperature: 1.2
# imself beginge. flowibled
# drepplibelss in
# his poed him, with him, norone every belly crying, too was tryms then. "didn't in year "i can
# ask eveor darking amand wombbloked, and the germed shige his four. hapenone son his and satitory
# as
# only, and lay
# footedusion. held her ther owa was
# not urmac of youritant colonel, midoniassa he could try," the plempered in rock wos, suph, candies, premermoard thr
# epoch 22
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.3022 - accuracy: 0.6032
# --- Generating with seed: "ttern answered."
#      "i wasn't even thinking about that!" c"
# ---- temperature: 0.2
# olonel cathcart scheisskopf and his poor of his hands of the street and shoulder of the start of the squadron when he said in the street and his fists of the street and had start of the second him and the best of the stop of the street and a stumpet of the streetly and shouting the chaplain was going to start of his second with a street and controls of the start of his head and stumbled the way to
# ---- temperature: 0.5
#  make him and the most the good and the still replied the puncised the stoul seventy who catern squadron and and saw you captain for the street of the way crew and the way that he was other same of the steepility and like a long on his life was a person was on the face voice and as he could be steen and because he was catch. gropiled like a cheer of even the good. the decided the enlight be a new
# ---- temperature: 1.0
# hage 1167heller, joseph: catch-22
# major --- de coverley idered corporbatly morely for all do you, no solon," capitte floving was snowd, didn, who did-colonel syid-forratk platels and
# dangess major. major mals this get bennw you. every norr. i to fighting pounding swiep you rook. here over you ourge caulble
# to there in the legs are
# geth fure."
#      "well,"
#      troney terrive steak them nothing res
# ---- temperature: 1.2
# tortaficiouslfom a beaf-b.ind yoursel of colonel korn was been
# velumsly that he madce stop wellence enespersone hands just with all an agoung, when who one
# cank usice tru.d, changed havolmy.
# crept exilder with liequeatocoss. "will you're's
# bohot
# to terr pitcible o thist this intenty."
# 22 ench
# strifqey dupt; there in the stumbing with alrow ittergning better teving
# in
# the sollegnia by willed with t
# epoch 23
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.2972 - accuracy: 0.6054
# --- Generating with seed: "sort of things?" yossarian interrupted with belligerent misg"
# ---- temperature: 0.2
# ed and was a clearing and the chaplain was stopped at the started and the bomb left and was a clearing his money to his face was a stranger of the chaplain was a misting in a stranger of a post the chaplain was a clearing and the plane was a bitch of the deaving the bard of the chaplain was a bear the plane was a strending the world was a cloved to the street because he was a bed and the chaplain
# ---- temperature: 0.5
# and every same that she father working. he had not never seed him with a morting and them was a moment of over the shather and then a half all his stubber to his flagger at in the time tritely as he was good. he was going to make the bombsible to decerter the tent all the men clothed at the the shooting before the mission to do who was a more. and he was there was not sure he was good colonel cath
# ---- temperature: 1.0
# cart who every
# good
# brought then perfocor. milo'ot for her gope all with the idey. "why do," mucked was
# to a
# real. "then we sury midd if he was good. alwout
# prisinges with you. do you know that? were what i'm not somewiding me by the bed, there is a supilately with
# impivitwher began."
#      seazed with hand, he had
# ripped and
# weven
# and duthaniand tongors!in in regtated that he blatuments aquaincy l
# ---- temperature: 1.2
# et eriving that you've ashaps for at then whire altered, by mectealy hadls threwly in a quesciaf getters on almots
# over voice dubbing was igh creasels and were inches all givinato, i'd have notr. you live you me gnind."
#      "wel hand
# even merniget," each of protting them uncensingembing, notece resofchesicoshienation and if her. yossarian tent and mouth whochatry jolend and thing-in his
# oppearuct
# epoch 24
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.2936 - accuracy: 0.6058
# --- Generating with seed: "army as a private and make him a major four days later so th"
# ---- temperature: 0.2
# e man shouted and the same the street because he was a hands. you know what you don't want to see the first the face with the street with the mission to him and was a second to make the same the same the same the same the street and shouted and the same the control to his face and shouted and shouting the strew had been shit of a confident and shouted at the started him any officers were a started
# ---- temperature: 0.5
#  to yossarian's way the orr was a whor he had no wing in the street of the sign of commanders with his eyes were a holding the feet for him and the best propled with the war work had office of the second was any poesh his shoulder with his the bomb leful about it was the men was spritenting to his enough an ele you come to a dead in milo and who came and would be and would not way in the more comb
# ---- temperature: 1.0
# at ans on the tanks from first," yossarian anstent peep but was an attingad
# initely delicerate and onder said out if an'me larged fool of growing to comke in but the'lle with a man were gooton come plaspiously."
# '  durrots was all the
# drobberitous it pleaded in the ward was dark, rit of the men formed with sho overceet sween in him.
#      "yes, i'm a would boy lieutenants," the ducked ender, and wi
# ---- temperature: 1.2
# th a ffided molochosolioply, are you?" yossarian trolient; it was five pistifted. who
# whole's from those blaker lift ount of befor yossaraan's simplited litures on.
#      "onesen am's ngring?"
#      "laarne? colone joing taloss and
# real-doiques, because just me side of he a secome. that's too
# coming out, did not thinkible in the city then there intwern how crap, toor cliet throw agad, her.      "goi
# epoch 25
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.2893 - accuracy: 0.6075
# --- Generating with seed: "nly sane one left."
# 11 captain black
#      corporal kolodny l"
# ---- temperature: 0.2
# eave the chaplain was a beal that he was a start who was a stranger of the same the same the same state and the same the same the same training and the same the same the same the same the same the same that he was strong the same the same the same the same the same the sleeped and shook and the chaplain began to the seconds and was a stranger of the same the same the same the same the same the sam
# ---- temperature: 0.5
# e drungle. "but that's a place and don't you to fill the name in such a new officers as he had to be a good and the bed who look and wound him out of the sat was the bedly and some spit. the only there he looked by the some toward his beung and the other despenia, and the chaplain and the targeating from the plane and the other stridge and she sense and shoulder the enlisted men like the strong on
# ---- temperature: 1.0
#  orr was and tobeenly insesquiture, a tingial plane in crimor of cat speently thaight, and boltfal desterat at old.
#      the hellong deforta to his fat flove
# had sky blord-ward. then help hone bombatiand down. "but i have brant in a tenking who were anywien't makn trying."
#      "that's something," everybody had cotton man wroms.
#      "you're talls have to gould till them, but scheissking, cit's no
# ---- temperature: 1.2
# r. hus she by yoursal about your madd with i'ld me see horsusent? sent doc? will
# thome, sip, sir."
#       hatched his line that flood, lose the poggueby and cacking in his
# typeps. and
# of corrocon cothalsing wither shooting and tunned until the chors over about yossarian,
# he could do, and
# yossarian did not luy and that nights of guy, of a xexat, much sister if like the resiaded out huaks the waverar
# epoch 26
# 2707/2707 [==============================] - 21s 8ms/step - loss: 1.2863 - accuracy: 0.6081
# --- Generating with seed: " i told them, and they thanked me and walked out together. h"
# ---- temperature: 0.2
# e was all the world with his shoulder and his left and the chaplain was a good of the street and the chaplain when he could not the bed the time the world, and he was all asked the sected him and the this and the chaplain was a start and contented with a but the chaplain was a start and compericate and complebing to his face and the world with his the mondious and she was a clain and the time the
# ---- temperature: 0.5
# ...
# ---- temperature: 1.0
# bought the down ob get italy him. they meen was to be four roar the reen people out. the oks
# willd be give subtilf's" nately officers hurring chaplain's plandiously lunging permitting figuisaniade turned od yossariant dobbs and dress. our
# enable centef in the mattarating actief
# yossarian and questing doad inly men with
# runnless of years that, i don't really raaming. you understand get a mechake, w
# ---- temperature: 1.2
# hat i meeny immens? that his mouming his why-seever eyens with yevendurously?' he fleves of the
# fluck tomiding by all," moured him, neving' then they could despoided and him. "subtiet eager. which hor of every meright him after his widewed up because his. he made my
# deab. the cheirscied,
# i am not to
# alvers chief white yaftly
# esteared feilom with? by the gener and his irnisedanut butchiogious plum
# epoch 52
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2197 - accuracy: 0.6262
# --- Generating with seed: "what targets have to be bombed."
#      "we are talking about "
# ---- temperature: 0.2
# to do with my condered."
#      "they got thinking that i were to be a completely in the man who was a bad to see the colonel korn was a real to all a streng holder that he was a plane and the chaplain was a bulby to the chaplain was a both a fact and shoot him and the chaplain was a closs of the man in the man who was a bulb struck and was a fact and the street and started him about the colonel moo
# ---- temperature: 0.5
# d and did not sure yossarian stouch out, and they were back in a few sendit," the chaplain was a place with an each of even that way the target and should i was something was a may of the control to find out of the room with shot on the chaplain state and forth streaming to go, he could have to be an ambuland. he are milo, and was to the chaplain began solenty confust martial whilpered and was a c
# ---- temperature: 1.0
# learf enough, alone. it were jublestly in her inquired. colonel cathcart turned or of the plendered
# tobverd out. doc'sered wasn't bet and tone again!"
#      "two'll so your half as macking would go say?" he catch-22
#      "oh tough rusite who
# wrangas!" sandy along because he was great clumble was the strangure of chally, wisth. "i'd long in throw," yossarian and and intercheed bannges and entiniand
# ---- temperature: 1.2
# falia curiouet officer snoulded his recage he flised floor, and a difes arear rindly for
# their equaller lose father who had. major wanted to proyotment and each
# sinightes. he couldn't red lounded theizzle, the mently chief and clapid but you back and pully."
#      "me you, nam," dobbed with
# gletting
# him friends over inashion of
# a guist-sage into his numped and writh swoke with collnsh with decughtl
# epoch 53
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2186 - accuracy: 0.6264
# --- Generating with seed: "o, of course not. that would be total capitulation. and i mi"
# ---- temperature: 0.2
# ght not going to come to look and sergeant towser is a second men in the country roared in the man who would be someone when he was surprise and the colonel korn was started in his strew he had stared and shouting a start with a buddled of the control of his the man so marrive start with a packed and shooting the men through the colonel cathcart was a second commandered and the way the colonel cat
# ---- temperature: 0.5
# hcart was climbing him and through the procide the suddenly. "i think they went a ling of the day before us a looking a person when he seemed to sure it that he's a problusing? you and he was bear in his from the only minute he had not that were from the regin and gave him and ever were and come to a few make him to the eduely to about the startive to be a punch sent how wonter meen with him and t
# ---- temperature: 1.0
# orr in only lost the bride! orders that she sweat, one state of the grewn elatul indeer in the good by like his head."
#      "her ferrar?" yossarian declared in hand texid, corporal carch surprised it was as even marring a craver. the dead smile of askempirged out of the corrom & m. generable
# the flight a beaming lies that was
# a move of the falling all reary buy to the funch, busticided. armuet ex-
# ---- temperature: 1.2
# -49-y
#      the chaplain wookelled was way. "i loughtur smacke" an weeked whough is. ordered a goalle, not curbed morminets corporbaciqually that the mygnamisting men sooving squarle!
# paging so contten open formord. get pilators, bin, the kipped with
# naxute you do wondered the ogsianignes. shrewdem's vain bomble?"
#      "ir able duck upleswers."
#      "i'm a dunco-me," the grooping her touriver
# epoch 54
# 2707/2707 [==============================] - 22s 8ms/step - loss: 1.2175 - accuracy: 0.6273
# --- Generating with seed: "nowden whimpered feebly over the intercom system then in a b"
# ---- temperature: 0.2
# rown and shoot his head in the strengtion and subleshing with a face with him and had standing at the strend and shot of the flak in a streng halls of the chaplain was a plane, was a face with esteration was a first and show him and a handsolfoly. it was a face with his head and shouldered the colonel was a bitch over the chaplain and a little to the first the stranger of the bombside in the face
# ---- temperature: 0.5
# or floor of him. he was and his fist day. the ground head in the chaplain eater at all and the about the dead who deterped in a striss to the only long can you suffy hard for the time it was in the officers in the all the first to sair in a sampart of the but shot for pression of a captain for a matter of a small that he had stapped a susped with a still and shoot all before the chaplain stamed wi
# ---- temperature: 1.0
# th hands to lieutenant mission, tell with waising upwittle. "how you get keep that firscred. out sighement who was
# a glash i dannsk and slit a deastickly to tudden, as he feelly the
# spacinger in it. our fertage to
# be name dobach he was enort same dry diees
# than he placed but woods for
# all, when colonel cathcart answering out
# yossaid waitcately in the
# nosicia. stude general very helt was luaunty as
# ---- temperature: 1.2
#  he hated yossarian,
# did the texan mindly pleadoy it's
# tent
# care of thus
# must captain-blacks!. everybody
# promissyon
# wrankorisistenthously through the groops of achass
# for squar-folentles who could confush-exepped to blab ther,' he was
# groups thristly. the
# gas forlle frantary and wold his second
# menti, general dreedle delinded half-stather and torgo, who deperberterstly in here with nece protect, w
# epoch 55
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2153 - accuracy: 0.6280
# --- Generating with seed: "ian urged. "you've finished your missions and you don't need"
# ---- temperature: 0.2
#  the next me."
#      "the colonel cathcart to be the only thing the hospital to see him not to the bartard and thing the most the posement and the barraring and the besisted him and through his head in the squadron and the barrarms with a buddle, and yossarian was a bulbas and the barrarms and black eyes of the bed the bed the chaplain was a bombs him to the brown. the chaplain was still a part of
# ---- temperature: 0.5
# the colonel cathcart. "shrimb, you'd better there i understand."
#      "have you ground hard!"
#      "i'm not to do beell milo, where it wasn't you hear she want to do it."
#      "that's good for her like the head it with my timid. i'm a clors of a person?"
#      "what about your forget to probably to kight," captain black eyes in the colonel know. dobbs who was a bombs said by the mission that orr wa
# ---- temperature: 1.0
# s a gife had glew just i madn he had the impsters, by the badder at citton. there were no big
# sneek and have very nose page 152heller, joseph: catch-22
#      "i can't now a grip, can taw," the issed to red flight dumps into ard the
# chippess.
# higaing who clothes in-"bulleg,
# sensible on him his giplal scheissel or with
# y.e."
#      "what ailits?"
#      "no." colonel cathcart had done emblense, crossed w
# ---- temperature: 1.2
# hile then
# back poolding
# jourls, on. as thr embaria aggeent twreet paying. and he crest without spacurage with joy's floon, for bushes. stood a mindilo for skipld over him. the nose?"
#      ides you scheisskopf," colonel korn collected the misget, at
# and he the
# roamon.
#      "gat neced court-enemmently. he mown? who wos then clept for inascenced.
#      there rulished in the six his confug allerian asl
# epoch 56
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2148 - accuracy: 0.6276
# --- Generating with seed: "t's and co-pilot's seats, pipe in hand, making affable small"
# ---- temperature: 0.2
#  of his face and the colonel mair. it was a first the works. he was as he was still the man she was a clearing for a states of the face with the way the only the bombs he was state and the partive and the man who was a first the chaplain with the chaplain with a state and the chaplain was stumbled of the same that he was still reported the colored man in a start the face with a start the same of t
# ---- temperature: 0.5
# he look of his the group half and would be a continue and he really down the chaplain in the squadron for him away."
#      "what didn't you should he had not going to stay. they got to go to the other stopped at the room to a commornit," the chaplain went in the bareful and forthous brooking from what he was a bitch of the other strong and contuntently all at him in the seconds and the thin the hos
# ---- temperature: 1.0
# empered marking deterge her eyes from him lieping strung her
# strew men parting the dest. "i'd like that i'd speaky was my narss, ank more
# his melispledyer it that their ement stark, the eng of him to dislair of go op!"
#      "why." colonel cathcart shoulder had wearted out
# and who weined the the agreed him of the way back at the whise, itnesse and wiging old gunnaged breaking, fives officer who cau
# ---- temperature: 1.2
# len come to keepirged of a, frightem. hus air? don colonel cathcer & t ench of
# the day along called eyes held him
# nommet that certain, who huctence new him streesing. but to ence mana, orr dnowmen tougoss up, his falls swacosary was tor
# pasts of them
# reperpeating targaliouss on the leniadmenes, bulbiated the hurving to corbid choriques. "white he had to have dow's nop back in the gladment know, hi
# epoch 57
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2126 - accuracy: 0.6283
# --- Generating with seed: "way their incentive."
#      milo was correct, of course, as e"
# ---- temperature: 0.2
# ven he was a comple right him to the still merally the street and like a from the ward and the fact and the broken and the time he was a plane and the time competited the air. "what the hell are you stop and that's what the hell anywer i asking to do you so making a little completely to the will that was the same the time the target and the their had state and the shooting his head and second comp
# ---- temperature: 0.5
# letely as he had never seen a sweet and reached more three of the ward from the both and shooted men was the orders with his work and laughed ex-p.s. a strend earling enough to do that was replied himself for the chaplain's back instrused because he was crettled and her ear the only one of the one of the hurting and left him of end state of the enough to do with a little she was the time he saw yo
# ---- temperature: 1.0
# u hows. as he about her could be
# talking. this they can cloblife! strucknessigh dististed.)
#      "do?" he read. he was dirncension was raditly with men like his trauched as though was a plane on the aboving his hind him and she faze, intercom. the word said. "i got know afica! it wanted to go is up."
#      "well and look, it's not. i peored, i hurt midd-" i'd
# want keep in providiggres of lieutenant
# ---- temperature: 1.2
# ' realioge, groth undle fint what he could noved merass spindly assust her sand,
# lieutent, where the saw elfoctop, and slophed; havided dort crasting turned of and were clove onlestle. yossarian
# had her--bulmuable minters. captain't at duckerity.
#      "well."
#      and
# i'm gone.
# certainle danbs,, hlisted the three and rameed to lumor and turnow the dropped him. "i
# hover. do?"
#      "no, have the oce
# epoch 58
# 2707/2707 [==============================] - 23s 8ms/step - loss: 1.2117 - accuracy: 0.6292
# --- Generating with seed: "ever he gets. don't you understand?"
#      but yossarian stil"
# ---- temperature: 0.2
# l dobbs were soon and shoot and thin or any of the strend and the chaplain is and the chaplain was strew him and the time to do and he was and the plane and then the chaplain was strew him and the same distraced with the streeting and shouting and the pitcess of the street and the based to do it with a parached with a streng hole and shoot his the sected him and shook his head and shot and shouted
# ---- temperature: 0.5
#  and shouted in the chaplain with a tent and share and ever sitter of the one of the chaplain with a start was pound the chaplain to deperate and contented in a fact and all the strong with good almost over his head in the shot on the day then nately's whore officer to see miness on the destroyed with his head and shouldered to the stride at the staid and can been to do that he was countence her a
# ---- temperature: 1.0
# rm country. i'm not to go over they said. i wouldn't gung
# my?" yossarian excaure-belfely, colonel korn. "oh, so it at "keep nairer a save pigult wisk of wave-s," dobbs with nower sergean in-tie soated cudstledding furing around hearch an about
# her most his ferts aponely koef that he had feil under ailless of otheats show."
#      yossarian seemed strew despeared for spititing. "to sere out if you am
# ---- temperature: 1.2
#  war inconed?"
#      "that's back into go, you and about their people, s coloomsarier," said. "to to orr, to about he don't like eagor to my basifal
# dreat?
# of the office another good overstang, pufflething ahe, me con't a crash
# at his feet inwerrawly, soldiers once simemps day tougorp suits with his. after havinbs wore and, she well bene or sugner who stared bulss gonely fresh-clothed his
# moveled c
# epoch 59
# 2707/2707 [==============================] - 23s 9ms/step - loss: 1.2128 - accuracy: 0.6282
# --- Generating with seed: "obably couldn't hear. yossarian, blazing with rage and almos"
# ---- temperature: 0.2
# t and see any more country with an avince himself and shook his head with the street and share and the ground him streamed at the hospital to him and the tent. he was stuld delight of the bomb right to the stumbled the colonel in the ward and the plane of the chaplain was stunners with a constantly in a streng had to the surprised him of the chaplain was group to him and the plane to the stumpets
# ---- temperature: 0.5
# and second countroes to the plane that he did not want to marry turning before he had to sin it, and you begin down on the world be the sweat of plane with his hands below he had all a shoulder girl them and his head at the stumbled them her away the mindation in the hospital to the bomb right to the word had stopped to him and part and struckned to the patacted with a ponty from the bed to streek
# ---- temperature: 1.0
# ed like a madnes of excevided that he reheishes, the chaplain voice ruttles long gustive them.
#      "chaplies?"
#      "relantacted," colonel korn returned's milliard page dately proted her signity at the chaplain was a lung. she
# wanted out for the hustianing omen that i tell having to do there was run group turn
# and put old your consausial sloplex you thin tiction. a
# facutan and, will had chasced b
# ---- temperature: 1.2
# eoo?"
#      "well, milo, you lged courtgey. yossarian, mustarily
# furbilligathet
# on the
# dubors toward yossarian had
# halfory to be someone add, rip! somposity mughtly. "he's over in the saw, they penswer to the thatigges and godded unselficle prindi of
# b.fighted her fresh to be attaid dack and then do do overhelly my in their room, fax people, a stuffered eyes
# afraid
# tame, say condledded to acraible

# %% [markdown]
# # Result
#
# ## Temperature 0.2
#
# ```
# and see any more country with an avince himself and shook his head with the
#
# street and share and the ground him streamed at the hospital to him and the
#
# tent.
#
# he was stuld delight of the bomb right to the stumbled the colonel in the ward
#
# and the plane of the chaplain was stunners with a constantly in a streng had to
#
# the surprised him of the chaplain was group to him and the plane to the stumpets
# ```
#
# ## Temperature 0.5
#
#
#
# ```
# and second countroes to the plane that he did not want to marry turning before
#
# he had to sin it, and you begin down on the world be the sweat of plane with
#
# his hands below he had all a shoulder girl them and his head at the stumbled
#
# them her away the mindation in the hospital to the bomb right to the word had
#
# stopped to him and part and struckned to the patacted with a ponty from the bed
#
# to streek
# ```
#
# ## Temperature 1.0
#
#
# ```
# ed like a madnes of excevided that he reheishes, the chaplain voice ruttles long gustive them.
#      "chaplies?"
#      "relantacted," colonel korn returned's milliard page dately proted her signity at the chaplain was a lung. she
# wanted out for the hustianing omen that i tell having to do there was run group turn
# and put old your consausial sloplex you thin tiction. a
# facutan and, will had chasced b
# ```
#
#
# ## Temperature 1.2
#
# ```
# eoo?"
#      "well, milo, you lged courtgey. yossarian, mustarily
# furbilligathet
# on the
# dubors toward yossarian had
# halfory to be someone add, rip! somposity mughtly. "he's over in the saw, they penswer to the thatigges and godded unselficle prindi of
# b.fighted her fresh to be attaid dack and then do do overhelly my in their room, fax people, a stuffered eyes
# afraid
# tame, say condledded to acraible
# ```
